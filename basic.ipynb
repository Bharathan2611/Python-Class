# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharathan2611/Python-Class/blob/main/basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Enter the Number")
# Out:
# Enter the Number

# %%
name="Bharathan" #String
print(name)
# Out:
# Bharathan
